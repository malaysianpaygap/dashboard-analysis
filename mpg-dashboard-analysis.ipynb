# %% [markdown]
# # 1) Importing the data

# %%
# default plot size [6.4, 4.8]

# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import date
import statistics as stats

# %%
# import data
dim_company_type = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_company_type.csv')
dim_educational_qualification = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_educational_qualification.csv')
dim_gender = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_gender.csv')
dim_industry = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_industry.csv')
dim_job_specialisation = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_job_specialisation.csv')
dim_nationality = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_nationality.csv')
dim_race = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_race.csv')
dim_source = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_source.csv')
dim_state = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_state.csv')
dim_working_arrangement = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\dim_working_arrangement.csv')
fact_job_details = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\fact_job_details.csv')
fact_submissions = pd.read_csv(r'C:\Users\Dante\Desktop\MPG\CSV files\fact_submissions.csv')

# %% [markdown]
# ## Merge fact_submissions

# %%
fact_submissions.head()
# Out:
#    submission_id           created_at  source_key  \
# 0              1  2022-03-10 12:51:52           1
# 1              2  2022-03-10 12:51:57           1
# 2              3  2022-03-10 12:52:04           1
# 3              4  2022-03-10 12:52:10           1
# 4              5  2022-03-10 12:52:21           1
#
#    educational_qualification_key  gender_key  nationality_key  race_key   age  \
# 0                              8           2                1         1  27.0
# 1                              5           2                1         1  23.0
# 2                              6           1                1         1  29.0
# 3                              5           2                1         1  27.0
# 4                              5           2                1         1  26.0
#
#    advice
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# join educational_qualification
fact_submissions = pd.merge(left = fact_submissions,
                            right = dim_educational_qualification,
                            how = 'left',
                           on = 'educational_qualification_key')
fact_submissions.drop(columns = ['educational_qualification_key', 'educational_qualification_bm'], inplace = True)

# join gender
fact_submissions = pd.merge(left = fact_submissions,
                            right = dim_gender,
                            how = 'left',
                            on = 'gender_key')
fact_submissions.drop(columns = ['gender_key', 'gender_bm'], inplace = True)

# join nationality
fact_submissions = pd.merge(left = fact_submissions,
                            right = dim_nationality,
                            how = 'left',
                            on = 'nationality_key')
fact_submissions.drop(columns = ['nationality_key', 'nationality_bm', 'code_alpha2', 'code_alpha3', 'region'], inplace = True)

# join race
fact_submissions = pd.merge(left = fact_submissions,
                            right = dim_race,
                            how = 'left',
                            on = 'race_key')
fact_submissions.drop(columns = ['race_key', 'race_bm'], inplace = True)

# %%
fact_submissions.head()
# Out:
#    submission_id           created_at  source_key   age  advice  \
# 0              1  2022-03-10 12:51:52           1  27.0     NaN
# 1              2  2022-03-10 12:51:57           1  23.0     NaN
# 2              3  2022-03-10 12:52:04           1  29.0     NaN
# 3              4  2022-03-10 12:52:10           1  27.0     NaN
# 4              5  2022-03-10 12:52:21           1  26.0     NaN
#
#    educational_qualification_en gender_en nationality_en  race_en
# 0    Master's Degree (Overseas)      Male       Malaysia  Chinese
# 1     Bachelor's Degree (Local)      Male       Malaysia  Chinese
# 2  Bachelor's Degree (Overseas)    Female       Malaysia  Chinese
# 3     Bachelor's Degree (Local)      Male       Malaysia  Chinese
# 4     Bachelor's Degree (Local)      Male       Malaysia  Chinese

# %% [markdown]
# ## Merge fact_job_details

# %%
fact_job_details.head()
# Out:
#    job_id  submission_id  total_experience_months  industry_key  \
# 0       1              1                       24          23.0
# 1       2              2                       12          23.0
# 2       3              3                       72           NaN
# 3       4              4                       36          23.0
# 4       5              5                       48          17.0
#
#    job_specialisation_key                          job_title  \
# 0                    20.0                       Data Analyst
# 1                    48.0                      IT specialist
# 2                    68.0                Product specialist
# 3                    20.0  Senior executive - Data Analytics
# 4                    69.0                    Demand Planner
#
#    company_type_key  gross_salary_myr  working_arrangement_key  \
# 0                 3            6700.0                        2
# 1                 3            5850.0                        1
# 2                 3            7500.0                        1
# 3                 3            3800.0                        2
# 4                 3           12000.0                        1
#
#    located_in_malaysia  state_key  avg_working_hours_per_day  \
# 0                 True          1                        8.0
# 1                 True          1                       10.0
# 2                 True          1                        9.0
# 3                 True         15                        8.0
# 4                 True          4                        8.0
#
#    avg_working_days_per_week  salary_compensation_satisfaction_score  \
# 0                        5.0                                       4
# 1                        5.0                                       4
# 2                        5.0                                       4
# 3                        5.0                                       4
# 4                        5.0                                       3
#
#    job_satisfaction_score                                  thoughts_comments
# 0                       3                                                NaN
# 1                       2  High salary but have to deal with very toxic m...
# 2                       4                                                NaN
# 3                       3                                                NaN
# 4                       3                                                NaN

# %%
# join industry
fact_job_details = pd.merge(left = fact_job_details,
                            right = dim_industry,
                            how = 'left',
                           on = 'industry_key')
fact_job_details.drop(columns = ['industry_key', 'industry_bm', 'industry_sub_definitions'], inplace = True)

# join job_specialisation
fact_job_details = pd.merge(left = fact_job_details,
                            right = dim_job_specialisation,
                            how = 'left',
                           on = 'job_specialisation_key')
fact_job_details.drop(columns = ['job_specialisation_key', 'job_specialisation_bm', 'job_specialisation_sub_definitions'], inplace = True)

# join company_type
fact_job_details = pd.merge(left = fact_job_details,
                            right = dim_company_type,
                            how = 'left',
                            on = 'company_type_key')
fact_job_details.drop(columns = ['company_type_key', 'company_type_bm'], inplace = True)

# join working_arrangement
fact_job_details = pd.merge(left = fact_job_details,
                            right = dim_working_arrangement,
                            how = 'left',
                            on = 'working_arrangement_key')
fact_job_details.drop(columns = ['working_arrangement_key', 'working_arrangement_bm'], inplace = True)

# join state
fact_job_details = pd.merge(left = fact_job_details,
                            right = dim_state,
                            how = 'left',
                            on = 'state_key')
fact_job_details.drop(columns = ['state_key', 'state_bm'], inplace = True)

# %%
fact_job_details.head()
# Out:
#    job_id  submission_id  total_experience_months  \
# 0       1              1                       24
# 1       2              2                       12
# 2       3              3                       72
# 3       4              4                       36
# 4       5              5                       48
#
#                            job_title  gross_salary_myr  located_in_malaysia  \
# 0                       Data Analyst            6700.0                 True
# 1                      IT specialist            5850.0                 True
# 2                Product specialist             7500.0                 True
# 3  Senior executive - Data Analytics            3800.0                 True
# 4                    Demand Planner            12000.0                 True
#
#    avg_working_hours_per_day  avg_working_days_per_week  \
# 0                        8.0                        5.0
# 1                       10.0                        5.0
# 2                        9.0                        5.0
# 3                        8.0                        5.0
# 4                        8.0                        5.0
#
#    salary_compensation_satisfaction_score  job_satisfaction_score  \
# 0                                       4                       3
# 1                                       4                       2
# 2                                       4                       4
# 3                                       4                       3
# 4                                       3                       3
#
#                                    thoughts_comments  \
# 0                                                NaN
# 1  High salary but have to deal with very toxic m...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          industry_en  \
# 0  Financial services / Investment / Banking / In...
# 1  Financial services / Investment / Banking / In...
# 2                                                NaN
# 3  Financial services / Investment / Banking / In...
# 4                                        Electronics
#
#                                job_specialisation_en  \
# 0  Data Scientists, Data Analytics, Data Engineer...
# 1  IT - Software and Web Developers, Programmers,...
# 2                     Project and Product Management
# 3  Data Scientists, Data Analytics, Data Engineer...
# 4  Purchasing, Procurement, Demand / Supply Plann...
#
#              company_type_en     working_arrangement_en  \
# 0  Multinational Corporation  Fully Working from Office
# 1  Multinational Corporation    Fully Working from Home
# 2  Multinational Corporation    Fully Working from Home
# 3  Multinational Corporation  Fully Working from Office
# 4  Multinational Corporation    Fully Working from Home
#
#                             state_en
# 0  Federal Territory of Kuala Lumpur
# 1  Federal Territory of Kuala Lumpur
# 2  Federal Territory of Kuala Lumpur
# 3                           Selangor
# 4                              Johor

# %% [markdown]
# # 2) Analysis

# %% [markdown]
# ## Benford's Law

# %%
# get first, second number of salary amounts
df_salary_int = pd.DataFrame()
df_salary_int['salary'] = fact_job_details['gross_salary_myr'].astype({'gross_salary_myr': 'int64'})
df_salary_int['first_digit'] = df_salary_int['salary'].astype(str).str[:1]
df_salary_int['second_digit'] = df_salary_int['salary'].astype(str).str[1:2]
df_salary_int
# Out:
#       salary first_digit second_digit
# 0       6700           6            7
# 1       5850           5            8
# 2       7500           7            5
# 3       3800           3            8
# 4      12000           1            2
# ...      ...         ...          ...
# 4571   14000           1            4
# 4572    3800           3            8
# 4573   11000           1            1
# 4574    4000           4            0
# 4575     670           6            7
#
# [4576 rows x 3 columns]

# %%
# histogram for first digit
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df_salary_int,
              y = 'first_digit',
             order = ['1','2','3','4','5','6','7','8','9','0'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='first_digit'>

# %%
df_first_digit_counts = pd.DataFrame()
df_first_digit_counts = df_salary_int.groupby(['first_digit']).size().to_frame('count')
df_first_digit_counts['percentage'] = 100 * (df_first_digit_counts['count']/len(df_salary_int))
df_first_digit_counts
# Out:
#              count  percentage
# first_digit
# 1              643   14.051573
# 2              706   15.428322
# 3             1061   23.186189
# 4              742   16.215035
# 5              498   10.882867
# 6              349    7.626748
# 7              268    5.856643
# 8              188    4.108392
# 9              121    2.644231

# %%
# histogram for second digit
fig, ax = plt.subplots(figsize=(10,5))
sns.countplot(data = df_salary_int,
              y = 'second_digit',
             order = ['1','2','3','4','5','6','7','8','9','0'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='second_digit'>

# %%
df_second_digit_counts = pd.DataFrame()
df_second_digit_counts = df_salary_int.groupby(['second_digit']).size().to_frame('count')
df_second_digit_counts['percentage'] = 100 * (df_second_digit_counts['count']/len(df_salary_int))
df_second_digit_counts
# Out:
#               count  percentage
# second_digit
#                   1    0.021853
# 0              1071   23.404720
# 1               308    6.730769
# 2               485   10.598776
# 3               416    9.090909
# 4               239    5.222902
# 5               765   16.717657
# 6               297    6.490385
# 7               305    6.665210
# 8               464   10.139860
# 9               225    4.916958

# %% [markdown]
# ## Submissions over time

# %%
fact_submissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4576 entries, 0 to 4575
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   submission_id                 4576 non-null   int64
#  1   created_at                    4576 non-null   object
#  2   source_key                    4576 non-null   int64
#  3   age                           4560 non-null   float64
#  4   advice                        0 non-null      float64
#  5   educational_qualification_en  4576 non-null   object
#  6   gender_en                     4576 non-null   object
#  7   nationality_en                4576 non-null   object
#  8   race_en                       4576 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 357.5+ KB

# %%
# make datetime type
fact_submissions = fact_submissions.astype({'created_at': 'datetime64'})

# new columns for separate date and time
fact_submissions['date'] = fact_submissions['created_at'].dt.date
fact_submissions['time'] = fact_submissions['created_at'].dt.time
fact_submissions = fact_submissions.astype({'date': 'datetime64'})

# %%
fact_submissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4576 entries, 0 to 4575
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   submission_id                 4576 non-null   int64
#  1   created_at                    4576 non-null   datetime64[ns]
#  2   source_key                    4576 non-null   int64
#  3   age                           4560 non-null   float64
#  4   advice                        0 non-null      float64
#  5   educational_qualification_en  4576 non-null   object
#  6   gender_en                     4576 non-null   object
#  7   nationality_en                4576 non-null   object
#  8   race_en                       4576 non-null   object
#  9   date                          4576 non-null   datetime64[ns]
#  10  time                          4576 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(5)
# memory usage: 429.0+ KB

# %%
fact_submissions['date'].head()
# Out:
# 0   2022-03-10
# 1   2022-03-10
# 2   2022-03-10
# 3   2022-03-10
# 4   2022-03-10
# Name: date, dtype: datetime64[ns]

# %%
fact_submissions['time'].head()
# Out:
# 0    12:51:52
# 1    12:51:57
# 2    12:52:04
# 3    12:52:10
# 4    12:52:21
# Name: time, dtype: object

# %%
# generate series from 1st of launch month to today
min_date = np.min(fact_submissions['date'])
dates = pd.date_range(start = min_date, end = date.today(), freq='D')
df_dates = pd.Series(dates).to_frame()
df_dates.columns = ['date']

# %%
df_dates.head()
# Out:
#         date
# 0 2022-03-10
# 1 2022-03-11
# 2 2022-03-12
# 3 2022-03-13
# 4 2022-03-14

# %%
fact_submissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4576 entries, 0 to 4575
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   submission_id                 4576 non-null   int64
#  1   created_at                    4576 non-null   datetime64[ns]
#  2   source_key                    4576 non-null   int64
#  3   age                           4560 non-null   float64
#  4   advice                        0 non-null      float64
#  5   educational_qualification_en  4576 non-null   object
#  6   gender_en                     4576 non-null   object
#  7   nationality_en                4576 non-null   object
#  8   race_en                       4576 non-null   object
#  9   date                          4576 non-null   datetime64[ns]
#  10  time                          4576 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(5)
# memory usage: 429.0+ KB

# %%
# get submission count for each day
df_submissions_per_day = fact_submissions.groupby('date').size().to_frame('count')
df_submissions_per_day.reset_index(inplace = True)

# %%
df_submissions_per_day = df_submissions_per_day.astype({'date': 'datetime64'})

# %%
# add col for cumulative submission count
df_submissions_per_day['cumulative_count'] = df_submissions_per_day['count'].cumsum()

# %%
df_submissions_per_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              83 non-null     datetime64[ns]
#  1   count             83 non-null     int64
#  2   cumulative_count  83 non-null     int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 2.1 KB

# %%
# merge
df_submissions_per_day = pd.merge(left = df_dates,
                                  right = df_submissions_per_day,
                                  how = 'left',
                                  on = 'date')

# %%
# add days since launch column
df_submissions_per_day['days_since_launch'] = df_submissions_per_day['date'] - min_date

# change to int
df_submissions_per_day['days_since_launch'] = df_submissions_per_day['days_since_launch'].dt.days

# %%
# fill down
df_submissions_per_day['cumulative_count'].ffill(axis = 0, inplace = True)

# fillna
df_submissions_per_day['cumulative_count'].fillna(value = 0, inplace = True)

# %%
df_submissions_per_day
# Out:
#          date   count  cumulative_count  days_since_launch
# 0  2022-03-10  2278.0            2278.0                  0
# 1  2022-03-11   396.0            2674.0                  1
# 2  2022-03-12    86.0            2760.0                  2
# 3  2022-03-13    40.0            2800.0                  3
# 4  2022-03-14   205.0            3005.0                  4
# ..        ...     ...               ...                ...
# 83 2022-06-01     6.0            4561.0                 83
# 84 2022-06-02     9.0            4570.0                 84
# 85 2022-06-03     4.0            4574.0                 85
# 86 2022-06-04     1.0            4575.0                 86
# 87 2022-06-05     1.0            4576.0                 87
#
# [88 rows x 4 columns]

# %%
df_submissions_per_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 0 to 87
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               88 non-null     datetime64[ns]
#  1   count              83 non-null     float64
#  2   cumulative_count   88 non-null     float64
#  3   days_since_launch  88 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 3.4 KB

# %%
# timeline of submissions
fig, ax = plt.subplots(figsize=(15,4.8))
sns.lineplot(data = df_submissions_per_day,
             x = 'date',
             y = 'cumulative_count',
             palette = 'pastel')
# Out:
# <AxesSubplot:xlabel='date', ylabel='cumulative_count'>

# %%
# timeline of submissions days since launch
fig, ax = plt.subplots(figsize=(15,4.8))
sns.lineplot(data = df_submissions_per_day,
             x = 'days_since_launch',
             y = 'cumulative_count',
             palette = 'pastel')
# Out:
# <AxesSubplot:xlabel='days_since_launch', ylabel='cumulative_count'>

# %% [markdown]
# ## Submissions per time of day

# %%
# change data type to string
fact_submissions = fact_submissions.astype({'time': 'string'})
fact_submissions['time'].head()
# Out:
# 0    12:51:52
# 1    12:51:57
# 2    12:52:04
# 3    12:52:10
# 4    12:52:21
# Name: time, dtype: string

# %%
len(fact_submissions['time'].unique())
# Out:
# 4369

# %%
# new time column without seconds
fact_submissions['rounded_time'] = fact_submissions['time'].str[:2]
fact_submissions['rounded_time'].head()
# Out:
# 0    12
# 1    12
# 2    12
# 3    12
# 4    12
# Name: rounded_time, dtype: string

# %%
len(fact_submissions['rounded_time'].unique())
# Out:
# 24

# %%
# get submission count for hour:min time
df_submissions_per_time = fact_submissions.groupby('rounded_time').size().to_frame('count')
df_submissions_per_time.reset_index(inplace = True)

# %%
df_submissions_per_time.head()
# Out:
#   rounded_time  count
# 0           00    142
# 1           01     70
# 2           02     42
# 3           03     25
# 4           04     13

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.countplot(data = fact_submissions,
              y = 'rounded_time',
              palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='count', ylabel='rounded_time'>

# %% [markdown]
# ## Submission demographics

# %%
# gender breakdown
fig, ax = plt.subplots(figsize=(6.4,7))
sns.countplot(data = fact_submissions,
              x = 'gender_en',
              palette = 'pastel')
# Out:
# <AxesSubplot:xlabel='gender_en', ylabel='count'>

# %%
# educational qualification breakdown
fig, ax = plt.subplots(figsize=(8,4.8))
sns.countplot(data = fact_submissions,
              y = 'educational_qualification_en',
              palette = 'Accent')
# Out:
# <AxesSubplot:xlabel='count', ylabel='educational_qualification_en'>

# %%
# race breakdown
fig, ax = plt.subplots(figsize=(8,4.8))
sns.countplot(data = fact_submissions,
              y = 'race_en',
              palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='count', ylabel='race_en'>

# %%
race_gender_breakdown = fact_submissions.groupby(['race_en', 'gender_en']).size().to_frame('count')
race_gender_breakdown.reset_index(inplace = True)

# %%
race_gender_breakdown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   race_en    18 non-null     object
#  1   gender_en  18 non-null     object
#  2   count      18 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 560.0+ bytes

# %%
race_gender_breakdown = race_gender_breakdown.pivot(index = 'gender_en', columns = 'race_en', values = 'count')
race_gender_breakdown
# Out:
# race_en            Chinese  Indian  Malay  Others  Sabahan Ethnic  \
# gender_en
# Female                1304     138    923      41              44
# Male                  1172     144    654      34              27
# Non-binary/others       17       2      8       3               1
#
# race_en            Sarawakian Ethnic
# gender_en
# Female                            38
# Male                              25
# Non-binary/others                  1

# %%
# race gender breakdown
fig, ax = plt.subplots(figsize=(8,4.8))
sns.countplot(data = fact_submissions,
              y = 'race_en',
              hue = 'gender_en',
              palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='count', ylabel='race_en'>

# %%
# edu race breakdown
edu_race_breakdown = fact_submissions.groupby(['race_en', 'educational_qualification_en']).size().to_frame('count')
edu_race_breakdown.reset_index(inplace = True)
edu_race_breakdown = edu_race_breakdown.pivot(index = 'educational_qualification_en', columns = 'race_en', values = 'count')
edu_race_breakdown
# Out:
# race_en                                Chinese  Indian  Malay  Others  \
# educational_qualification_en
# Bachelor's Degree (Local)               1392.0   150.0  971.0    34.0
# Bachelor's Degree (Overseas)             470.0    41.0  217.0    20.0
# Diploma                                  111.0    18.0   60.0     6.0
# Diploma/Professional Certification(s)    105.0    13.0   70.0     6.0
# High School                               63.0    11.0   26.0     5.0
# Master's Degree (Local)                  150.0    36.0  127.0     3.0
# Master's Degree (Overseas)               126.0     6.0   68.0     2.0
# PhD (Local)                                9.0     1.0    3.0     NaN
# PhD (Overseas)                             NaN     1.0    5.0     NaN
# Professional Certification(s)             67.0     7.0   38.0     2.0
#
# race_en                                Sabahan Ethnic  Sarawakian Ethnic
# educational_qualification_en
# Bachelor's Degree (Local)                        43.0               33.0
# Bachelor's Degree (Overseas)                     10.0                7.0
# Diploma                                           3.0                7.0
# Diploma/Professional Certification(s)             5.0                2.0
# High School                                       3.0                1.0
# Master's Degree (Local)                           3.0                7.0
# Master's Degree (Overseas)                        1.0                4.0
# PhD (Local)                                       NaN                NaN
# PhD (Overseas)                                    1.0                NaN
# Professional Certification(s)                     3.0                3.0

# %%
# edu race breakdown
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(data = fact_submissions,
              y = 'educational_qualification_en',
              hue = 'race_en',
              palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='count', ylabel='educational_qualification_en'>

# %%
# edu gender breakdown
edu_gender_breakdown = fact_submissions.groupby(['gender_en', 'educational_qualification_en']).size().to_frame('count')
edu_gender_breakdown.reset_index(inplace = True)
edu_gender_breakdown = edu_gender_breakdown.pivot(index = 'educational_qualification_en', columns = 'gender_en', values = 'count')
edu_gender_breakdown
# Out:
# gender_en                              Female    Male  Non-binary/others
# educational_qualification_en
# Bachelor's Degree (Local)              1487.0  1119.0               17.0
# Bachelor's Degree (Overseas)            380.0   378.0                7.0
# Diploma                                 105.0    99.0                1.0
# Diploma/Professional Certification(s)   109.0    91.0                1.0
# High School                              46.0    60.0                3.0
# Master's Degree (Local)                 189.0   135.0                2.0
# Master's Degree (Overseas)               95.0   112.0                NaN
# PhD (Local)                               5.0     8.0                NaN
# PhD (Overseas)                            5.0     2.0                NaN
# Professional Certification(s)            67.0    52.0                1.0

# %%
# edu gender breakdown
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(data = fact_submissions,
              y = 'educational_qualification_en',
              hue = 'gender_en',
              palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='count', ylabel='educational_qualification_en'>

# %% [markdown]
# ## Statistics

# %%
fact_job_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4576 entries, 0 to 4575
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   job_id                                  4576 non-null   int64
#  1   submission_id                           4576 non-null   int64
#  2   total_experience_months                 4576 non-null   int64
#  3   job_title                               4576 non-null   object
#  4   gross_salary_myr                        4576 non-null   float64
#  5   located_in_malaysia                     4576 non-null   bool
#  6   avg_working_hours_per_day               4576 non-null   float64
#  7   avg_working_days_per_week               4576 non-null   float64
#  8   salary_compensation_satisfaction_score  4576 non-null   int64
#  9   job_satisfaction_score                  4576 non-null   int64
#  10  thoughts_comments                       2300 non-null   object
#  11  industry_en                             3420 non-null   object
#  12  job_specialisation_en                   3885 non-null   object
#  13  company_type_en                         4576 non-null   object
#  14  working_arrangement_en                  4576 non-null   object
#  15  state_en                                4576 non-null   object
# dtypes: bool(1), float64(3), int64(5), object(7)
# memory usage: 576.5+ KB

# %%
# salary distribution
fig, ax = plt.subplots(figsize=(25,6))
sns.histplot(data = fact_job_details,
             x = 'gross_salary_myr',
             binwidth = 1000)
# Out:
# <AxesSubplot:xlabel='gross_salary_myr', ylabel='Count'>

# %%
# function for summary statistics
def calculate_summary_statistics(df, col, col_print_flag):
    if col_print_flag == 1:
        print(col)
        
    print("    Min : {:.1f}".format(df[col].min()))
    print("    Max : {:.1f}".format(df[col].max()))
    print("    Mean : {:.1f}".format(df[col].mean()))
    print("    Median : {:.1f}".format(df[col].median()))
    print("    Standard Deviation : {:.1f}".format(stats.stdev(df[col])))

# %%
col_list = ['gross_salary_myr', 'total_experience_months', 'avg_working_hours_per_day', 'avg_working_days_per_week', 'salary_compensation_satisfaction_score', 'job_satisfaction_score']

for col in col_list:
    calculate_summary_statistics(fact_job_details, col, 1)
# Out:
# gross_salary_myr
#     Min : 1.0
#     Max : 300000.0
#     Mean : 6526.6
#     Median : 4500.0
#     Standard Deviation : 9571.0
# total_experience_months
#     Min : 0.0
#     Max : 936.0
#     Mean : 56.6
#     Median : 48.0
#     Standard Deviation : 49.7
# avg_working_hours_per_day
#     Min : 1.0
#     Max : 24.0
#     Mean : 8.8
#     Median : 8.0
#     Standard Deviation : 1.6
# avg_working_days_per_week
#     Min : 2.0
#     Max : 7.0
#     Mean : 5.2
#     Median : 5.0
#     Standard Deviation : 0.5
# salary_compensation_satisfaction_score
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.2
#     Median : 3.0
#     Standard Deviation : 1.1
# job_satisfaction_score
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.4
#     Median : 4.0
#     Standard Deviation : 1.1

# %%
# company type difference
col_diff = 'working_arrangement_en'
col_list = ['gross_salary_myr', 'avg_working_hours_per_day', 'avg_working_days_per_week', 'salary_compensation_satisfaction_score', 'job_satisfaction_score']
for col in col_list:    
    list_company_type = list(fact_job_details[col_diff].unique())
    print(col)
    for company_type in list_company_type:
        fact_job_details_company_type = fact_job_details[fact_job_details[col_diff] == company_type]
        print(company_type)
        calculate_summary_statistics(fact_job_details_company_type, col, 0)
    print('')
# Out:
# gross_salary_myr
# Fully Working from Office
#     Min : 600.0
#     Max : 250000.0
#     Mean : 5452.1
#     Median : 3900.0
#     Standard Deviation : 8138.2
# Fully Working from Home
#     Min : 1.0
#     Max : 100000.0
#     Mean : 6831.1
#     Median : 4900.0
#     Standard Deviation : 6606.9
# Hybrid
#     Min : 1200.0
#     Max : 300000.0
#     Mean : 7707.0
#     Median : 5200.0
#     Standard Deviation : 11979.6
#
# avg_working_hours_per_day
# Fully Working from Office
#     Min : 2.0
#     Max : 24.0
#     Mean : 8.9
#     Median : 8.5
#     Standard Deviation : 1.5
# Fully Working from Home
#     Min : 1.0
#     Max : 24.0
#     Mean : 8.4
#     Median : 8.0
#     Standard Deviation : 1.8
# Hybrid
#     Min : 3.0
#     Max : 24.0
#     Mean : 8.8
#     Median : 8.0
#     Standard Deviation : 1.6
#
# avg_working_days_per_week
# Fully Working from Office
#     Min : 3.0
#     Max : 7.0
#     Mean : 5.2
#     Median : 5.0
#     Standard Deviation : 0.5
# Fully Working from Home
#     Min : 2.0
#     Max : 7.0
#     Mean : 5.1
#     Median : 5.0
#     Standard Deviation : 0.4
# Hybrid
#     Min : 3.0
#     Max : 7.0
#     Mean : 5.1
#     Median : 5.0
#     Standard Deviation : 0.4
#
# salary_compensation_satisfaction_score
# Fully Working from Office
#     Min : 1.0
#     Max : 5.0
#     Mean : 2.9
#     Median : 3.0
#     Standard Deviation : 1.1
# Fully Working from Home
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.5
#     Median : 4.0
#     Standard Deviation : 1.1
# Hybrid
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.3
#     Median : 3.0
#     Standard Deviation : 1.1
#
# job_satisfaction_score
# Fully Working from Office
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.2
#     Median : 3.0
#     Standard Deviation : 1.1
# Fully Working from Home
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.7
#     Median : 4.0
#     Standard Deviation : 1.1
# Hybrid
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.6
#     Median : 4.0
#     Standard Deviation : 1.0

# %%
# company type difference
col_diff = 'state_en'
col_list = ['gross_salary_myr', 'avg_working_hours_per_day', 'avg_working_days_per_week', 'salary_compensation_satisfaction_score', 'job_satisfaction_score']
for col in col_list:    
    list_company_type = list(fact_job_details[col_diff].unique())
    print(col)
    for company_type in list_company_type:
        fact_job_details_company_type = fact_job_details[fact_job_details[col_diff] == company_type]
        print(company_type)
        calculate_summary_statistics(fact_job_details_company_type, col, 0)
    print('')
# Out:
# gross_salary_myr
# Federal Territory of Kuala Lumpur
#     Min : 1.0
#     Max : 300000.0
#     Mean : 7450.6
#     Median : 5000.0
#     Standard Deviation : 11107.4
# Selangor
#     Min : 30.0
#     Max : 128844.0
#     Mean : 5982.6
#     Median : 4374.5
#     Standard Deviation : 6866.4
# Johor
#     Min : 1150.0
#     Max : 220500.0
#     Mean : 5950.6
#     Median : 3800.0
#     Standard Deviation : 15412.6
# Penang
#     Min : 52.0
#     Max : 170000.0
#     Mean : 5789.5
#     Median : 4225.0
#     Standard Deviation : 9583.4
# Sarawak
#     Min : 670.0
#     Max : 27000.0
#     Mean : 5266.3
#     Median : 3350.0
#     Standard Deviation : 5330.2
# Perak
#     Min : 1200.0
#     Max : 28560.0
#     Mean : 4415.3
#     Median : 3060.0
#     Standard Deviation : 4574.7
# Kedah
#     Min : 1000.0
#     Max : 18000.0
#     Mean : 4365.6
#     Median : 3500.0
#     Standard Deviation : 3169.2
# Negeri Sembilan
#     Min : 1400.0
#     Max : 52000.0
#     Mean : 6563.1
#     Median : 4100.0
#     Standard Deviation : 8152.9
# Sabah
#     Min : 1300.0
#     Max : 27000.0
#     Mean : 4841.7
#     Median : 3000.0
#     Standard Deviation : 4553.1
# Pahang
#     Min : 1200.0
#     Max : 60000.0
#     Mean : 6466.7
#     Median : 3650.0
#     Standard Deviation : 10434.8
# Terengganu
#     Min : 1200.0
#     Max : 24500.0
#     Mean : 6057.4
#     Median : 4900.0
#     Standard Deviation : 5657.7
# Malacca
#     Min : 1500.0
#     Max : 13000.0
#     Mean : 4810.3
#     Median : 3750.0
#     Standard Deviation : 2853.3
# Federal Territory of Putrajaya
#     Min : 1200.0
#     Max : 11500.0
#     Mean : 5219.0
#     Median : 4048.0
#     Standard Deviation : 2905.1
# Kelantan
#     Min : 1200.0
#     Max : 14300.0
#     Mean : 5740.0
#     Median : 4800.0
#     Standard Deviation : 3977.1
# Federal Territory of Labuan
#     Min : 1800.0
#     Max : 9580.0
#     Mean : 4422.0
#     Median : 3135.0
#     Standard Deviation : 2791.4
# Perlis
#     Min : 3000.0
#     Max : 4700.0
#     Mean : 3790.0
#     Median : 3670.0
#     Standard Deviation : 856.3
#
# avg_working_hours_per_day
# Federal Territory of Kuala Lumpur
#     Min : 2.0
#     Max : 24.0
#     Mean : 8.9
#     Median : 8.0
#     Standard Deviation : 1.7
# Selangor
#     Min : 1.0
#     Max : 24.0
#     Mean : 8.7
#     Median : 8.0
#     Standard Deviation : 1.6
# Johor
#     Min : 5.0
#     Max : 24.0
#     Mean : 8.9
#     Median : 8.5
#     Standard Deviation : 1.9
# Penang
#     Min : 4.0
#     Max : 13.0
#     Mean : 8.8
#     Median : 8.5
#     Standard Deviation : 1.4
# Sarawak
#     Min : 5.0
#     Max : 12.0
#     Mean : 8.5
#     Median : 8.0
#     Standard Deviation : 1.4
# Perak
#     Min : 3.0
#     Max : 14.0
#     Mean : 8.6
#     Median : 8.5
#     Standard Deviation : 1.6
# Kedah
#     Min : 4.0
#     Max : 11.0
#     Mean : 8.1
#     Median : 8.0
#     Standard Deviation : 1.2
# Negeri Sembilan
#     Min : 4.0
#     Max : 15.0
#     Mean : 8.6
#     Median : 8.0
#     Standard Deviation : 1.7
# Sabah
#     Min : 7.0
#     Max : 14.0
#     Mean : 8.6
#     Median : 8.0
#     Standard Deviation : 1.3
# Pahang
#     Min : 4.0
#     Max : 13.0
#     Mean : 8.5
#     Median : 8.0
#     Standard Deviation : 1.4
# Terengganu
#     Min : 7.0
#     Max : 14.0
#     Mean : 9.3
#     Median : 9.0
#     Standard Deviation : 1.8
# Malacca
#     Min : 6.0
#     Max : 13.0
#     Mean : 8.6
#     Median : 8.2
#     Standard Deviation : 1.1
# Federal Territory of Putrajaya
#     Min : 8.0
#     Max : 11.0
#     Mean : 8.7
#     Median : 8.0
#     Standard Deviation : 0.9
# Kelantan
#     Min : 5.0
#     Max : 12.0
#     Mean : 8.0
#     Median : 8.0
#     Standard Deviation : 1.9
# Federal Territory of Labuan
#     Min : 8.0
#     Max : 12.0
#     Mean : 8.9
#     Median : 8.0
#     Standard Deviation : 1.5
# Perlis
#     Min : 8.0
#     Max : 12.0
#     Mean : 10.3
#     Median : 11.0
#     Standard Deviation : 2.1
#
# avg_working_days_per_week
# Federal Territory of Kuala Lumpur
#     Min : 3.0
#     Max : 7.0
#     Mean : 5.1
#     Median : 5.0
#     Standard Deviation : 0.4
# Selangor
#     Min : 2.0
#     Max : 7.0
#     Mean : 5.2
#     Median : 5.0
#     Standard Deviation : 0.5
# Johor
#     Min : 4.0
#     Max : 7.0
#     Mean : 5.2
#     Median : 5.0
#     Standard Deviation : 0.5
# Penang
#     Min : 3.0
#     Max : 7.0
#     Mean : 5.1
#     Median : 5.0
#     Standard Deviation : 0.4
# Sarawak
#     Min : 4.0
#     Max : 7.0
#     Mean : 5.4
#     Median : 5.0
#     Standard Deviation : 0.5
# Perak
#     Min : 3.0
#     Max : 7.0
#     Mean : 5.4
#     Median : 5.0
#     Standard Deviation : 0.7
# Kedah
#     Min : 5.0
#     Max : 7.0
#     Mean : 5.2
#     Median : 5.0
#     Standard Deviation : 0.5
# Negeri Sembilan
#     Min : 5.0
#     Max : 7.0
#     Mean : 5.2
#     Median : 5.0
#     Standard Deviation : 0.5
# Sabah
#     Min : 5.0
#     Max : 7.0
#     Mean : 5.3
#     Median : 5.0
#     Standard Deviation : 0.5
# Pahang
#     Min : 4.0
#     Max : 7.0
#     Mean : 5.4
#     Median : 5.0
#     Standard Deviation : 0.7
# Terengganu
#     Min : 4.0
#     Max : 6.2
#     Mean : 5.3
#     Median : 5.0
#     Standard Deviation : 0.6
# Malacca
#     Min : 4.5
#     Max : 7.0
#     Mean : 5.2
#     Median : 5.0
#     Standard Deviation : 0.5
# Federal Territory of Putrajaya
#     Min : 5.0
#     Max : 6.0
#     Mean : 5.2
#     Median : 5.0
#     Standard Deviation : 0.4
# Kelantan
#     Min : 4.0
#     Max : 6.0
#     Mean : 5.2
#     Median : 5.0
#     Standard Deviation : 0.6
# Federal Territory of Labuan
#     Min : 5.0
#     Max : 7.0
#     Mean : 5.4
#     Median : 5.0
#     Standard Deviation : 0.8
# Perlis
#     Min : 5.0
#     Max : 5.0
#     Mean : 5.0
#     Median : 5.0
#     Standard Deviation : 0.0
#
# salary_compensation_satisfaction_score
# Federal Territory of Kuala Lumpur
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.3
#     Median : 3.0
#     Standard Deviation : 1.1
# Selangor
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.1
#     Median : 3.0
#     Standard Deviation : 1.1
# Johor
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.0
#     Median : 3.0
#     Standard Deviation : 1.1
# Penang
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.1
#     Median : 3.0
#     Standard Deviation : 1.1
# Sarawak
#     Min : 1.0
#     Max : 5.0
#     Mean : 2.8
#     Median : 3.0
#     Standard Deviation : 1.2
# Perak
#     Min : 1.0
#     Max : 5.0
#     Mean : 2.8
#     Median : 3.0
#     Standard Deviation : 1.3
# Kedah
#     Min : 1.0
#     Max : 5.0
#     Mean : 2.8
#     Median : 3.0
#     Standard Deviation : 1.2
# Negeri Sembilan
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.1
#     Median : 3.0
#     Standard Deviation : 1.1
# Sabah
#     Min : 1.0
#     Max : 5.0
#     Mean : 2.8
#     Median : 3.0
#     Standard Deviation : 1.2
# Pahang
#     Min : 1.0
#     Max : 4.0
#     Mean : 2.9
#     Median : 3.0
#     Standard Deviation : 1.0
# Terengganu
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.2
#     Median : 3.0
#     Standard Deviation : 1.2
# Malacca
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.2
#     Median : 3.0
#     Standard Deviation : 1.0
# Federal Territory of Putrajaya
#     Min : 1.0
#     Max : 4.0
#     Mean : 2.9
#     Median : 3.0
#     Standard Deviation : 1.0
# Kelantan
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.4
#     Median : 3.5
#     Standard Deviation : 1.5
# Federal Territory of Labuan
#     Min : 1.0
#     Max : 4.0
#     Mean : 2.6
#     Median : 3.0
#     Standard Deviation : 1.0
# Perlis
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.3
#     Median : 4.0
#     Standard Deviation : 2.1
#
# job_satisfaction_score
# Federal Territory of Kuala Lumpur
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.5
#     Median : 4.0
#     Standard Deviation : 1.1
# Selangor
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.4
#     Median : 4.0
#     Standard Deviation : 1.1
# Johor
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.3
#     Median : 3.0
#     Standard Deviation : 1.1
# Penang
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.4
#     Median : 3.5
#     Standard Deviation : 1.1
# Sarawak
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.2
#     Median : 3.0
#     Standard Deviation : 1.1
# Perak
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.2
#     Median : 3.0
#     Standard Deviation : 1.2
# Kedah
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.3
#     Median : 3.0
#     Standard Deviation : 1.2
# Negeri Sembilan
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.3
#     Median : 3.0
#     Standard Deviation : 1.2
# Sabah
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.0
#     Median : 3.0
#     Standard Deviation : 1.2
# Pahang
#     Min : 2.0
#     Max : 5.0
#     Mean : 3.2
#     Median : 3.0
#     Standard Deviation : 0.8
# Terengganu
#     Min : 2.0
#     Max : 5.0
#     Mean : 3.5
#     Median : 3.0
#     Standard Deviation : 1.1
# Malacca
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.4
#     Median : 3.0
#     Standard Deviation : 1.1
# Federal Territory of Putrajaya
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.0
#     Median : 3.0
#     Standard Deviation : 1.3
# Kelantan
#     Min : 1.0
#     Max : 5.0
#     Mean : 3.7
#     Median : 4.0
#     Standard Deviation : 1.4
# Federal Territory of Labuan
#     Min : 1.0
#     Max : 4.0
#     Mean : 3.0
#     Median : 3.0
#     Standard Deviation : 1.2
# Perlis
#     Min : 1.0
#     Max : 4.0
#     Mean : 2.7
#     Median : 3.0
#     Standard Deviation : 1.5

# %%
fact_job_details[fact_job_details['avg_working_hours_per_day'] == 24]
# Out:
#       job_id  submission_id  total_experience_months  \
# 95        96             96                      192
# 1114    1115           1115                      120
# 1617    1618           1618                       36
# 3865    3866           3866                       60
# 4533    4534           4534                       48
#
#                                         job_title  gross_salary_myr  \
# 95                               Slave at YouTube           20000.0
# 1114               Senior Database Admin Engineer            9500.0
# 1617                          Petroleum surveyor             7500.0
# 3865                           Executive Director           30000.0
# 4533  Senior Online Customer Service (E-commerce)            5000.0
#
#       located_in_malaysia  avg_working_hours_per_day  \
# 95                   True                       24.0
# 1114                 True                       24.0
# 1617                 True                       24.0
# 3865                 True                       24.0
# 4533                 True                       24.0
#
#       avg_working_days_per_week  salary_compensation_satisfaction_score  \
# 95                          7.0                                       5
# 1114                        7.0                                       4
# 1617                        4.0                                       4
# 3865                        7.0                                       3
# 4533                        5.0                                       3
#
#       job_satisfaction_score                        thoughts_comments  \
# 95                         5                        The start is hard
# 1114                       4                 Submit on behalf husband
# 1617                       4                                      NaN
# 3865                       3  basically im the boss. working 24/7/365
# 4533                       3                                      NaN
#
#                                             industry_en  \
# 95                                                Media
# 1114                                                NaN
# 1617                                          Oil & Gas
# 3865  Financial services / Investment / Banking / In...
# 4533                                                NaN
#
#                                   job_specialisation_en  \
# 95      Communication - Public Relations (PR) and Media
# 1114  IT - Database, Network and Systems Administrat...
# 1617  Consulting - Consultants, Analysts, Advisors, ...
# 3865                                                NaN
# 4533                                                NaN
#
#                       company_type_en     working_arrangement_en  \
# 95            Freelance/Self-employed    Fully Working from Home
# 1114        Multinational Corporation                     Hybrid
# 1617        Multinational Corporation  Fully Working from Office
# 3865  Small & Medium-sized Enterprise                     Hybrid
# 4533  Small & Medium-sized Enterprise  Fully Working from Office
#
#                                state_en
# 95    Federal Territory of Kuala Lumpur
# 1114                           Selangor
# 1617                              Johor
# 3865  Federal Territory of Kuala Lumpur
# 4533                           Selangor

# %%
fact_job_details[fact_job_details['avg_working_days_per_week'] == 7]
# Out:
#       job_id  submission_id  total_experience_months  \
# 54        55             55                       36
# 95        96             96                      192
# 111      112            112                       48
# 227      228            228                       36
# 293      294            294                       24
# ...      ...            ...                      ...
# 4503    4504           4504                       72
# 4519    4520           4520                       12
# 4529    4530           4530                        5
# 4544    4545           4545                      108
# 4570    4571           4571                       12
#
#                                   job_title  gross_salary_myr  \
# 54                                 Engineer           15000.0
# 95                         Slave at YouTube           20000.0
# 111                                 Teacher            3000.0
# 227                              Copywriter            4400.0
# 293   Senior Associate, Campaign Management            7200.0
# ...                                     ...               ...
# 4503                          Media Officer            3700.0
# 4519                                Analyst            3200.0
# 4529            Coding for Kids instructor              800.0
# 4544                        Insurance Agent           25000.0
# 4570                          Media Planner            2800.0
#
#       located_in_malaysia  avg_working_hours_per_day  \
# 54                   True                       12.0
# 95                   True                       24.0
# 111                  True                       11.0
# 227                  True                        8.0
# 293                  True                       12.0
# ...                   ...                        ...
# 4503                 True                        9.0
# 4519                 True                        8.0
# 4529                 True                        9.0
# 4544                 True                        6.0
# 4570                 True                       15.0
#
#       avg_working_days_per_week  salary_compensation_satisfaction_score  \
# 54                          7.0                                       2
# 95                          7.0                                       5
# 111                         7.0                                       2
# 227                         7.0                                       3
# 293                         7.0                                       4
# ...                         ...                                     ...
# 4503                        7.0                                       3
# 4519                        7.0                                       4
# 4529                        7.0                                       1
# 4544                        7.0                                       5
# 4570                        7.0                                       2
#
#       job_satisfaction_score  \
# 54                         2
# 95                         5
# 111                        2
# 227                        4
# 293                        2
# ...                      ...
# 4503                       4
# 4519                       3
# 4529                       3
# 4544                       5
# 4570                       4
#
#                                       thoughts_comments  \
# 54                                                  NaN
# 95                                    The start is hard
# 111                                                 NaN
# 227   Coming from a law background to the creative i...
# 293                                                 NaN
# ...                                                 ...
# 4503  I am a Team Media Officer who worked for 2 Mal...
# 4519  Now even private sector pay more, even freshgr...
# 4529  It's upsetting that I can't even earn 3K after...
# 4544                            Hustle hard when young!
# 4570  Work 24/7, weird request from client that thin...
#
#                      industry_en  \
# 54    Telecommunication Services
# 95                         Media
# 111                    Education
# 227     Advertising & Marketing
# 293          E-commerce & Retail
# ...                          ...
# 4503                         NaN
# 4519                         NaN
# 4529                         NaN
# 4544                         NaN
# 4570                         NaN
#
#                                   job_specialisation_en  \
# 54    Customer Service and Customer / Community Rela...
# 95      Communication - Public Relations (PR) and Media
# 111                              Teaching and Education
# 227   Communication - Copywriters, Intepretors and T...
# 293                      Project and Product Management
# ...                                                 ...
# 4503                                                NaN
# 4519                                                NaN
# 4529                                                NaN
# 4544                                                NaN
# 4570                                                NaN
#
#                       company_type_en     working_arrangement_en  \
# 54          Multinational Corporation  Fully Working from Office
# 95            Freelance/Self-employed    Fully Working from Home
# 111   Small & Medium-sized Enterprise  Fully Working from Office
# 227   Small & Medium-sized Enterprise  Fully Working from Office
# 293         Multinational Corporation                     Hybrid
# ...                               ...                        ...
# 4503        Multinational Corporation  Fully Working from Office
# 4519        Multinational Corporation                     Hybrid
# 4529  Small & Medium-sized Enterprise    Fully Working from Home
# 4544        Multinational Corporation                     Hybrid
# 4570                       Non-profit                     Hybrid
#
#                                state_en
# 54    Federal Territory of Kuala Lumpur
# 95    Federal Territory of Kuala Lumpur
# 111                            Selangor
# 227   Federal Territory of Kuala Lumpur
# 293   Federal Territory of Kuala Lumpur
# ...                                 ...
# 4503  Federal Territory of Kuala Lumpur
# 4519                              Johor
# 4529                           Selangor
# 4544                           Selangor
# 4570  Federal Territory of Kuala Lumpur
#
# [101 rows x 16 columns]
